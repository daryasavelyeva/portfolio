# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Подготовка-данных" data-toc-modified-id="Подготовка-данных-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Подготовка данных</a></span><ul class="toc-item"><li><span><a href="#Изучение-общей-информации" data-toc-modified-id="Изучение-общей-информации-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Изучение общей информации</a></span></li><li><span><a href="#Проверка-расчета-эффективности-обогащения" data-toc-modified-id="Проверка-расчета-эффективности-обогащения-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Проверка расчета эффективности обогащения</a></span></li><li><span><a href="#Анализ-признаков,-недоступных-в-тестовой-выборке" data-toc-modified-id="Анализ-признаков,-недоступных-в-тестовой-выборке-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Анализ признаков, недоступных в тестовой выборке</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Анализ-данных" data-toc-modified-id="Анализ-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Анализ данных</a></span><ul class="toc-item"><li><span><a href="#Изменение-концентрации-металлов-(Au,-Ag,-Pb)-на-различных-этапах-очистки" data-toc-modified-id="Изменение-концентрации-металлов-(Au,-Ag,-Pb)-на-различных-этапах-очистки-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Изменение концентрации металлов (Au, Ag, Pb) на различных этапах очистки</a></span></li><li><span><a href="#Распределение-размеров-гранул-сырья-на-обучающей-и-тестовой-выборках" data-toc-modified-id="Распределение-размеров-гранул-сырья-на-обучающей-и-тестовой-выборках-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Распределение размеров гранул сырья на обучающей и тестовой выборках</a></span></li><li><span><a href="#Суммарная-концентрация-всех-веществ-на-разных-стадиях:-в-сырье,-в-черновом-и-финальном-концентратах" data-toc-modified-id="Суммарная-концентрация-всех-веществ-на-разных-стадиях:-в-сырье,-в-черновом-и-финальном-концентратах-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Суммарная концентрация всех веществ на разных стадиях: в сырье, в черновом и финальном концентратах</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Работа-с-моделями" data-toc-modified-id="Работа-с-моделями-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Работа с моделями</a></span><ul class="toc-item"><li><span><a href="#Разбивка-данных-на-выборки" data-toc-modified-id="Разбивка-данных-на-выборки-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Разбивка данных на выборки</a></span></li><li><span><a href="#Функция-для-вычисления-итоговой-sMAPE" data-toc-modified-id="Функция-для-вычисления-итоговой-sMAPE-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Функция для вычисления итоговой sMAPE</a></span></li><li><span><a href="#Обучение-моделей-и-оценка-их-качества" data-toc-modified-id="Обучение-моделей-и-оценка-их-качества-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Обучение моделей и оценка их качества</a></span></li><li><span><a href="#Тестирование-модели" data-toc-modified-id="Тестирование-модели-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Тестирование модели</a></span></li><li><span><a href="#Проверка-модели-на-адекватность" data-toc-modified-id="Проверка-модели-на-адекватность-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Проверка модели на адекватность</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-3.6"><span class="toc-item-num">3.6&nbsp;&nbsp;</span>Вывод</a></span></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-3.7"><span class="toc-item-num">3.7&nbsp;&nbsp;</span>Общий вывод</a></span></li></ul></li><li><span><a href="#Чек-лист-готовности-проекта" data-toc-modified-id="Чек-лист-готовности-проекта-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Чек-лист готовности проекта</a></span></li></ul></div>

# %% [markdown]
# <div class = "alert alert-info" style="border-left: 7px solid blue">
# <b>Комментарий студента</b>
#
# Павел, привет) спасибо тебе большое!) Исправила ошибку - объявила date индексом и удалось улучшить значение sMAPE :)
#
# </div>

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера: </b></font> ✔️\
# <font color='green'> Отлично! Теперь таргеты точно соответствуют своис фичам! ))</font>

# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Подготовка-данных" data-toc-modified-id="Подготовка-данных-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Подготовка данных</a></span><ul class="toc-item"><li><span><a href="#Изучение-общей-информации" data-toc-modified-id="Изучение-общей-информации-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Изучение общей информации</a></span></li><li><span><a href="#Проверка-расчета-эффективности-обогащения" data-toc-modified-id="Проверка-расчета-эффективности-обогащения-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Проверка расчета эффективности обогащения</a></span></li><li><span><a href="#Анализ-признаков,-недоступных-в-тестовой-выборке" data-toc-modified-id="Анализ-признаков,-недоступных-в-тестовой-выборке-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Анализ признаков, недоступных в тестовой выборке</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Анализ-данных" data-toc-modified-id="Анализ-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Анализ данных</a></span><ul class="toc-item"><li><span><a href="#Изменение-концентрации-металлов-(Au,-Ag,-Pb)-на-различных-этапах-очистки" data-toc-modified-id="Изменение-концентрации-металлов-(Au,-Ag,-Pb)-на-различных-этапах-очистки-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Изменение концентрации металлов (Au, Ag, Pb) на различных этапах очистки</a></span></li><li><span><a href="#Распределение-размеров-гранул-сырья-на-обучающей-и-тестовой-выборках" data-toc-modified-id="Распределение-размеров-гранул-сырья-на-обучающей-и-тестовой-выборках-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Распределение размеров гранул сырья на обучающей и тестовой выборках</a></span></li><li><span><a href="#Суммарная-концентрация-всех-веществ-на-разных-стадиях:-в-сырье,-в-черновом-и-финальном-концентратах" data-toc-modified-id="Суммарная-концентрация-всех-веществ-на-разных-стадиях:-в-сырье,-в-черновом-и-финальном-концентратах-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Суммарная концентрация всех веществ на разных стадиях: в сырье, в черновом и финальном концентратах</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Работа-с-моделями" data-toc-modified-id="Работа-с-моделями-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Работа с моделями</a></span><ul class="toc-item"><li><span><a href="#Разбивка-данных-на-выборки" data-toc-modified-id="Разбивка-данных-на-выборки-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Разбивка данных на выборки</a></span></li><li><span><a href="#Функция-для-вычисления-итоговой-sMAPE" data-toc-modified-id="Функция-для-вычисления-итоговой-sMAPE-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Функция для вычисления итоговой sMAPE</a></span></li><li><span><a href="#Обучение-моделей-и-оценка-их-качества" data-toc-modified-id="Обучение-моделей-и-оценка-их-качества-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Обучение моделей и оценка их качества</a></span></li><li><span><a href="#Тестирование-модели" data-toc-modified-id="Тестирование-модели-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Тестирование модели</a></span></li><li><span><a href="#Проверка-модели-на-адекватность" data-toc-modified-id="Проверка-модели-на-адекватность-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Проверка модели на адекватность</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-3.6"><span class="toc-item-num">3.6&nbsp;&nbsp;</span>Вывод</a></span></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-3.7"><span class="toc-item-num">3.7&nbsp;&nbsp;</span>Общий вывод</a></span></li></ul></li><li><span><a href="#Чек-лист-готовности-проекта" data-toc-modified-id="Чек-лист-готовности-проекта-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Чек-лист готовности проекта</a></span></li></ul></div>

# %% [markdown]
# # Восстановление золота из руды

# %% [markdown]
# Подготовьте прототип модели машинного обучения для компании, разрабатывающей решения для эффективной работы промышленных предприятий.
#
# Модель должна предсказать коэффициент восстановления золота из золотосодержащей руды. Используйте данные с параметрами добычи и очистки.
#
# Модель поможет оптимизировать производство, чтобы не запускать предприятие с убыточными характеристиками.
#
#
# **Описание проекта**
#
# Данные находятся в трёх файлах:
#
# - `gold_recovery_train_new.csv` — обучающая выборка;
# - `gold_recovery_test_new.csv` — тестовая выборка;
# - `gold_recovery_full_new.csv` — исходные данные.
#
# Данные индексируются датой и временем получения информации (признак `date`). Соседние по времени параметры часто похожи.
#
# Некоторые параметры недоступны, потому что замеряются и/или рассчитываются значительно позже. Из-за этого в тестовой выборке отсутствуют некоторые признаки, которые могут быть в обучающей. Также в тестовом наборе нет целевых признаков.
#
# Исходный датасет содержит обучающую и тестовую выборки со всеми признаками.
#
# В вашем распоряжении сырые данные: их просто выгрузили из хранилища. Прежде чем приступить к построению модели, проверьте по нашей инструкции их на корректность.
#
# **План исследования**
#
# 1. Подготовка данных
# - 1.1. Изучение данных
# - 1.2. Проверка верности расчета эффективности обогащения. Её вычисление на обучающей выборке для признака `rougher.output.recovery`. Вычисление MAE между расчётами и значением признака, описание выводов
# - 1.3. Анализ признаков, недоступных в тестовой выборке
# - 1.4. Предобработка данных
#
# 2. Анализ данных
# - 2.1. Изменение концентрации металлов (*Au, Ag, Pb*) на различных этапах очистки
# - 2.2. Сравнение распределения размеров гранул сырья на обучающей и тестовой выборках (если распределения сильно отличаются друг от друга, оценка модели будет неправильной)
# - 2.3. Исследование суммарной концентрации всех веществ на разных стадиях: в сырье, в черновом и финальном концентратах
#
# 3. Построение моделей
# - 3.1. Создание функции для вычисления итоговой *sMAPE*.
# - 3.2. Обучение нескольких моделей и оценка их качества кросс-валидацией. Выбор лучшей модели и проверка её на тестовой выборке. Общие выводы

# %% [markdown]
# ## Подготовка данных

# %% [markdown]
# ### Изучение общей информации
#
# Загрузим необходимые библиотеки:

# %%
import pandas as pd
pd.set_option('display.max_columns', None) 
pd.set_option('display.max_rows', None) 
pd.options.mode.chained_assignment = None

from sklearn.linear_model import LinearRegression 
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn.dummy import DummyRegressor

from sklearn.metrics import make_scorer, mean_absolute_error

import matplotlib.pyplot as plt
import seaborn as sns

import numpy as np
from numpy.random import RandomState

# %% [markdown]
# Загрузим данные:

# %%
try:
    data_full = pd.read_csv('/datasets/gold_recovery_full_new.csv')
    data_train = pd.read_csv('/datasets/gold_recovery_train_new.csv')
    data_test = pd.read_csv('/datasets/gold_recovery_test_new.csv')
except:
    data_full = pd.read_csv('/Users/Dasha/General_Project_2_gold_ore/gold_recovery_full_new.csv')
    data_train = pd.read_csv('/Users/Dasha/General_Project_2_gold_ore/gold_recovery_train_new.csv')
    data_test = pd.read_csv('/Users/Dasha/General_Project_2_gold_ore/gold_recovery_test_new.csv')

# %% [markdown]
# Напишем функцию для изучения информации о данных:

# %%
def get_data_name(data):
    name =[x for x in globals() if globals()[x] is data][0]
    return name

datas = [data_full, data_train, data_test]
for data in datas:
    print('\n\033[1m' + 'Информация о датафрейме', get_data_name(data), '\n')
    print('Первые пять строк:' + '\033[0m')
    display(data.head())
    print('\n\033[1m' + 'Общая информация:\n' + '\033[0m')
    data.info()
    print('\n\033[1m' + 'Описательная статистика:\n' + '\033[0m')
    display(data.describe())
    print('\n\033[1m' + 'Кол-во явных дубликатов:\n' + '\033[0m')
    display(data.duplicated().sum())
    print('\n\033[1m' + 'Количество пропусков:\n' + '\033[0m')
    display(data.isna().sum())
    print('__________________________________')
# Out:
# Информация о датафрейме data_full
#
# Первые пять строк:
#                   date  final.output.concentrate_ag  \
# 0  2016-01-15 00:00:00                     6.055403
# 1  2016-01-15 01:00:00                     6.029369
# 2  2016-01-15 02:00:00                     6.055926
# 3  2016-01-15 03:00:00                     6.047977
# 4  2016-01-15 04:00:00                     6.148599
#
#    final.output.concentrate_pb  final.output.concentrate_sol  \
# 0                     9.889648                      5.507324
# 1                     9.968944                      5.257781
# 2                    10.213995                      5.383759
# 3                     9.977019                      4.858634
# 4                    10.142511                      4.939416
#
#    final.output.concentrate_au  final.output.recovery  final.output.tail_ag  \
# 0                    42.192020              70.541216             10.411962
# ...

# %% [markdown]
# Создадим функцию для построения матрицы корреляции и посмотрим, есть линейная зависимость между признаками в полной выборке:

# %%
def corr_graphics(data):
    
    # выводим название датасета
    print([x for x in globals() if globals()[x] is data][0])
    
    #построение корреляционной матрицы
    plt.figure(figsize=(10, 10))
    corr_matrix = sns.heatmap(data.corr())
    corr_matrix.axes.set_title('Матрица корреляции', fontsize=14)

# %%
corr_graphics(data_full)
# Out:
# data_full

# %% [markdown]
# Матрица корреляции показывает, что между некоторыми признаками есть сильная прямая либо обратная корреляция.
#
# При изучении данных явных дубликатов и проблем с типом данных не обнаружено. Во всех датасетах присутствуют пропуски.
# В описании проекта сказано, что данные индексируются датой и временем получения информации (признак `date`). Соседние по времени параметры часто похожи, поэтому:
#
# - установим столбец `date` в качестве индекса
# - заполним пропуски в исходном датасете на предшествующее нулю значение

# %%
data_full.set_index('date', inplace=True)
data_train.set_index('date', inplace=True)
data_test.set_index('date', inplace=True)
display(data_full.head(1))
display(data_train.head(1))
display(data_test.head(1))
# Out:
#                      final.output.concentrate_ag  final.output.concentrate_pb  \
# date
# 2016-01-15 00:00:00                     6.055403                     9.889648
#
#                      final.output.concentrate_sol  \
# date
# 2016-01-15 00:00:00                      5.507324
#
#                      final.output.concentrate_au  final.output.recovery  \
# date
# 2016-01-15 00:00:00                     42.19202              70.541216
#
#                      final.output.tail_ag  final.output.tail_pb  \
# date
# 2016-01-15 00:00:00             10.411962              0.895447
#
#                      final.output.tail_sol  final.output.tail_au  \
# date
# 2016-01-15 00:00:00              16.904297              2.143149
#
#                      primary_cleaner.input.sulfate  \
# date
# 2016-01-15 00:00:00                     127.092003
#
#                      primary_cleaner.input.depressant  \
# date
# 2016-01-15 00:00:00                         10.128295
#
# ...

# %%
data_full = data_full.fillna(method='ffill')

# %% [markdown]
# В обучающей и тестовой выборках заменим пропуски значениями из исходных данных:

# %%
data_train = data_train.fillna(data_full)
data_test = data_test.fillna(data_full)

# %% [markdown]
# Проверим результат заполнения пропусков:

# %%
def get_data_name(data):
    name =[x for x in globals() if globals()[x] is data][0]
    return name

datas = [data_full, data_train, data_test]
for data in datas:
    print('\n\033[1m' + 'Информация о датафрейме', get_data_name(data), '\n' + '\033[0m')
    print('Количество пропусков:', data.isna().sum().sum())
    print('__________________________________')
# Out:
# Информация о датафрейме data_full
#
# Количество пропусков: 0
# __________________________________
#
# Информация о датафрейме data_train
#
# Количество пропусков: 0
# __________________________________
#
# Информация о датафрейме data_test
#
# Количество пропусков: 0
# __________________________________

# %% [markdown]
# ### Проверка расчета эффективности обогащения
#
# Проверим, что эффективность обогащения рассчитана правильно:
#
# - Вычислим её на обучающей выборке для признака `rougher.output.recovery`
# - Найдем *MAE* между нашими расчётами и значением признака

# %%
C = data_train['rougher.output.concentrate_au'] # доля золота в концентрате после флотации/очистки
F = data_train['rougher.input.feed_au'] # доля золота в сырье/концентрате до флотации/очистки
T = data_train['rougher.output.tail_au'] # доля золота в отвальных хвостах после флотации/очистки

# %%
# формула расчета эффективности обогащения
recovery = (C * (F - T)) / (F * (C - T)) * 100

# %%
print(f"Среднеее значение эффективности обогащения = {recovery.mean()}")
print(f"MAE = {mean_absolute_error(data_train['rougher.output.recovery'], recovery)}")
# Out:
# Среднеее значение эффективности обогащения = 82.70450164550269
# MAE = 9.73512347450521e-15

# %% [markdown]
# Значение средней абсолютной ошибки стремится к нулю, значит, расчет произведен верно.

# %% [markdown]
# ### Анализ признаков, недоступных в тестовой выборке
#
# Создадим список `missing_columns` с названиями признаков, которые есть в обучающей выборке, но отсутствуют в тестовой:

# %%
missing_columns = set(data_train.columns) - set(data_test.columns)
missing_columns
# Out:
# {'final.output.concentrate_ag',
#  'final.output.concentrate_au',
#  'final.output.concentrate_pb',
#  'final.output.concentrate_sol',
#  'final.output.recovery',
#  'final.output.tail_ag',
#  'final.output.tail_au',
#  'final.output.tail_pb',
#  'final.output.tail_sol',
#  'primary_cleaner.output.concentrate_ag',
#  'primary_cleaner.output.concentrate_au',
#  'primary_cleaner.output.concentrate_pb',
#  'primary_cleaner.output.concentrate_sol',
#  'primary_cleaner.output.tail_ag',
#  'primary_cleaner.output.tail_au',
#  'primary_cleaner.output.tail_pb',
#  'primary_cleaner.output.tail_sol',
#  'rougher.calculation.au_pb_ratio',
#  'rougher.calculation.floatbank10_sulfate_to_au_feed',
#  'rougher.calculation.floatbank11_sulfate_to_au_feed',
#  'rougher.calculation.sulfate_to_au_concentrate',
#  'rougher.output.concentrate_ag',
#  'rougher.output.concentrate_au',
#  'rougher.output.concentrate_pb',
#  'rougher.output.concentrate_sol',
#  'rougher.output.recovery',
# ...

# %% [markdown]
# Признаки, отсутствующие в тестовой выборке - в основном, хвосты и консистенции металлов на различных этапах. Удалим их из обучающей выборки:

# %%
data_train = data_train.drop(missing_columns, axis=1)

# %% [markdown]
# Проверим результат удаления:

# %%
print(data_train.shape)
print(data_test.shape)
# Out:
# (14149, 52)
# (5290, 52)

# %% [markdown]
# ### Вывод
#
# В ходе подготовки данных мы выяснили:
#
# - Явных дубликатов и проблем с типом данных не обнаружено. Так как по условию задачи данные индексируются датой и временем получения информации, мы установили столбец `date` в качестве индекса. Также было сказано, что соседние по времени параметры часто похожи, поэтому пропуски в исходном датасете были заменены на предшествующее нулю значение, далее пропуски в обучающей и тестовой выборках были заполнены данными из исходного датасета
#
# - Между некоторыми признаками есть сильная прямая либо обратная корреляция
#
# - Эффективность обогащения рассчитана правильно - *MAE* между нашим расчетом на обучающей выборке и значением признака `rougher.output.recovery` стремится к нулю
#
# - Признаки, отсутствующие в тестовой выборке - в основном, хвосты и консистенции металлов на различных этапах. Мы удалили данные признаки из обучающей выборки.

# %% [markdown]
# ## Анализ данных
#
# ### Изменение концентрации металлов (Au, Ag, Pb) на различных этапах очистки
#
# Построим график, иллюстрирующий концентрацию золота на различных этапах очистки:

# %%
def metal_concentrate (metal, name):
    """ Рисуем график, иллюстрирующий концентрацию золота на различных этапах очистки
    metal = обозначение металла
    name = название металла
    """
    
    plt.figure(figsize=(15,5))
    
    sns.histplot(data_full[f'rougher.input.feed_{metal}'], color='b', 
                 label='Исходное сырье', element='step', bins=100, alpha=.6)
    sns.histplot(data_full[f'rougher.output.concentrate_{metal}'], color='g', 
                 label='Флотация', element='step', bins=100, alpha=.6)
    sns.histplot(data_full[f'primary_cleaner.output.concentrate_{metal}'], color='orange', 
                 label='Первичная очистка', bins=100, element='step', alpha=.6)
    sns.histplot(data_full[f'final.output.concentrate_{metal}'], color='deeppink', 
                 label='Финальная', bins=100, element='step', alpha=.6)
    
    plt.title(f'Концентрация {name} на различных этапах очистки', fontsize=15)
    plt.xlabel(f'Концентрация')
    plt.ylabel(f'Количество')
    plt.legend()
    plt.show()

# %%
metal_concentrate ('au', 'золота')

# %%
metal_concentrate ('ag', 'серебра')

# %%
metal_concentrate ('pb', 'свинца')

# %% [markdown]
# Из графиков мы видим, что на различных этапах очистки:
#
# - концентрация золота повышается с каждым этапом
# - концентрация серебра увеличивается после флотации, затем идет на спад
# - концентрация свинца увеличивается с каждым этапом
# - также присутствуют аномальные значения в районе нуля

# %% [markdown]
# ### Распределение размеров гранул сырья на обучающей и тестовой выборках
#
# Сравним, отличается ли распределение размеров гранул сырья на обучающей и тестовой выборках

# %%
def feed_size (step, name):
    
    plt.figure(figsize=(15, 5))
    
    sns.histplot(data_train[f'{step}.feed_size'], color='orange', label='Обучающая выборка', 
                 element='step', bins=100, alpha=.6)
    sns.histplot(data_test[f'{step}.feed_size'], color='deeppink', label='Тестовая выборка', 
                 element='step', bins=100, alpha=.6)
    
    plt.title(f'Распределение размеров гранул {name}', fontsize=15)
    plt.xlabel('Размер гранул сырья')
    plt.ylabel('Количество')
    plt.legend()
    plt.show()

# %%
feed_size('rougher.input', 'исходного сырья')

# %%
feed_size('primary_cleaner.input', 'сырья после первичной обработки')

# %% [markdown]
# На графиках видно, что размер гранул сырья на обучающей и тестовой выборках имеет схожее распределение.

# %% [markdown]
# ### Суммарная концентрация всех веществ на разных стадиях: в сырье, в черновом и финальном концентратах
#
# Посчитаем суммарную концентрацию всех веществ на разных стадиях:

# %%
# суммарная концентрация металлов в исходном сырье
feed_concentrate = (data_full['rougher.input.feed_au']
                    + data_full['rougher.input.feed_ag']  
                    + data_full['rougher.input.feed_pb'] 
                    + data_full['rougher.input.feed_sol'])

# суммарная концентрация металлов после флотации
rougher_concentrate = (data_full['rougher.output.concentrate_au'] 
                       + data_full['rougher.output.concentrate_ag'] 
                       + data_full['rougher.output.concentrate_pb'] 
                       + data_full['rougher.output.concentrate_sol'])

# суммарная концентрация металлов после первичной очистки
primary_cleaner_concentrate = (data_full['primary_cleaner.output.concentrate_au'] 
                               + data_full['primary_cleaner.output.concentrate_ag'] 
                               + data_full['primary_cleaner.output.concentrate_pb'] 
                               + data_full['primary_cleaner.output.concentrate_sol'])

# финальная суммарная концентрация металлов
final_concentrate = (data_full['final.output.concentrate_au'] 
                     + data_full['final.output.concentrate_ag'] 
                     + data_full['final.output.concentrate_pb'] 
                     + data_full['final.output.concentrate_sol'])

# %% [markdown]
# Построим график распределения суммарной концентрации всех веществ на разных стадиях:

# %%
plt.figure(figsize=(15,5))
    
sns.histplot(feed_concentrate, color='b', 
                 label='Исходное сырье', element='step', bins=100, alpha=.6)
sns.histplot(rougher_concentrate, color='g', 
                 label='Флотация', element='step', bins=100, alpha=.6)
sns.histplot(primary_cleaner_concentrate, color='orange', 
                 label='Первичная очистка', bins=100, element='step', alpha=.6)
sns.histplot(final_concentrate, color='deeppink', 
                 label='Финальная', bins=100, element='step', alpha=.6)
    
plt.title(f'Суммарная концентрация всех веществ на разных стадиях', fontsize=15)
plt.xlabel(f'Концентрация')
plt.ylabel(f'Количество')
plt.legend()
plt.show()

# %% [markdown]
#  - Мы видим, что суммарная концентрация веществ увеличивается с каждым этапом, на этапе флотации и финальном этапе концентрация похожа, однако, распределение в финальном концентрате более собранное
#  - Также мы видим значения суммарной концентрации веществ около нуля, что маловероятно - скорее всего, это ошибка в данных и мы имеем дело с выбросами.
#
# Произведем удаление выбросов во всех датасетах, оставив только значения суммарной концентрации веществ больше 3:

# %%
# удаление выбросов в исходном датасете
data_full = data_full.query('@feed_concentrate > 3 & @rougher_concentrate > 3 \
                            & @primary_cleaner_concentrate > 3 & @final_concentrate > 3')

# удаление выбросов в обучающей выборке
data_train = data_train.query('@feed_concentrate > 3 & @rougher_concentrate > 3 \
                            & @primary_cleaner_concentrate > 3 & @final_concentrate > 3')

# удаление выбросов в тестовой выборке
data_test = data_test.query('@feed_concentrate > 3 & @rougher_concentrate > 3 \
                            & @primary_cleaner_concentrate > 3 & @final_concentrate > 3')

# %% [markdown]
# ### Вывод
#
# - Построив график распределения концентрации металлов (Au, Ag, Pb) на различных этапах очистки, мы увидели:
#   - концентрация золота и свинца повышается с каждым этапом
#   - концентрация серебра увеличивается после флотации, затем идет на спад
#   - присутствуют аномальные значения в районе нуля
#
# - График распределения размеров гранул сырья на обучающей и тестовой выборках показал схожее распределение
#
# - Суммарная концентрация веществ увеличивается на каждом этапе и достигает максимальных значения на этапе флотации и финальной стадии, однако, распределение в финальном концентрате более собранное
#
# - В суммарной концентрации веществ снова всплыли значения в районе нуля, которые мы удалили, оставив только значения суммарной концентрации веществ больше 3

# %% [markdown]
# ## Работа с моделями
#
# ### Разбивка данных на выборки
#
# Добавим в обучающую и тестовую выборки целевые признаки из исходной выборки:

# %%
data_train = pd.merge(data_train, 
                     data_full[['rougher.output.recovery', 'final.output.recovery']],
                     left_index=True,
                     right_index=True)

data_test = pd.merge(data_test, 
                     data_full[['rougher.output.recovery', 'final.output.recovery']],
                     left_index=True,
                     right_index=True)

data_train.info()
data_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13591 entries, 2016-01-15 00:00:00 to 2018-08-18 10:59:59
# Data columns (total 54 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   primary_cleaner.input.sulfate               13591 non-null  float64
#  1   primary_cleaner.input.depressant            13591 non-null  float64
#  2   primary_cleaner.input.feed_size             13591 non-null  float64
#  3   primary_cleaner.input.xanthate              13591 non-null  float64
#  4   primary_cleaner.state.floatbank8_a_air      13591 non-null  float64
#  5   primary_cleaner.state.floatbank8_a_level    13591 non-null  float64
#  6   primary_cleaner.state.floatbank8_b_air      13591 non-null  float64
#  7   primary_cleaner.state.floatbank8_b_level    13591 non-null  float64
#  8   primary_cleaner.state.floatbank8_c_air      13591 non-null  float64
# ...

# %% [markdown]
# Разделим обучающую выборку на признаки и целевой признак:

# %%
# сохраним признаки
features_train = data_train.drop(['rougher.output.recovery', 'final.output.recovery'], axis=1)

# сохраним целевой признак
target_train = data_train[['rougher.output.recovery', 'final.output.recovery']]

display(features_train.shape)
display(target_train.shape)
# Out:
# (13591, 52)
# (13591, 2)

# %% [markdown]
# Разделим тестовую выборку на признаки и целевой признак:

# %%
# сохраним признаки
features_test = data_test.drop(['rougher.output.recovery', 'final.output.recovery'], axis=1)

# сохраним целевой признак
target_test = data_test[['rougher.output.recovery', 'final.output.recovery']]

display(features_test.shape)
display(target_test.shape)
# Out:
# (5118, 52)
# (5118, 2)

# %% [markdown]
# ### Функция для вычисления итоговой sMAPE
#
# Создадим функцию для расчета метрики качества *sMAPE* (англ. *Symmetric Mean Absolute Percentage Error*, «симметричное среднее абсолютное процентное отклонение»), которая принимает на вход целевой признак и предсказания:

# %% [markdown]
# ![Image.png](attachment:Image.png)

# %%
def smape(target, predictions):
    return 1 / len(target) * np.sum(2 * np.abs(target - predictions) 
                                    / (np.abs(target) + np.abs(predictions)) * 100)

# %% [markdown]
# Также создадим функция для итоговой метрики *sMAPE*, которая складывается из двух величин:
# - эффективность обогащения чернового концентрата `rougher.output.recovery`
# - эффективность обогащения финального концентрата `final.output.recovery`
#
# На вход функция также принимает целевой признак и предсказания:

# %% [markdown]
# ![Image-2.png](attachment:Image-2.png)

# %%
def final_smape(target, predictions):
    smape_rougher = smape(target['rougher.output.recovery'], predictions[:, 0])
    smape_final = smape(target['final.output.recovery'], predictions[:, 1])
    
    final_smape = (smape_rougher * 0.25) + (smape_final * 0.75)
    
    return final_smape

# %% [markdown]
# Создадим метрику оценки качества модели `smape_scorer`:

# %%
smape_scorer = make_scorer(final_smape, greater_is_better=False)

# %% [markdown]
# ### Обучение моделей и оценка их качества
#
# Обучим и оценим качество трех моделей: *линейная регрессия*, *дерево решений* и *случайный лес*

# %% [markdown]
# **Линейная регрессия**
#
# Обучим модель и оценим ее качество с помощью кросс-валидации:

# %%
lr_model = LinearRegression()

score = cross_val_score(lr_model, features_train, target_train, cv=5, scoring=smape_scorer).mean()

print('Среднее значение sMAPE для модели LinearRegression = ', score)
# Out:
# Среднее значение sMAPE для модели LinearRegression =  -10.098769922418116

# %% [markdown]
# **Дерево решений**
#
# Обучим модель, используя автоматический подбор лучших гиперпараметров с помощью GridSearchCV, и оценим результат ее работы:

# %%
# настроим псевдослучайность выбора
STATE = np.random.RandomState(12345)

# %%
dtr_model = DecisionTreeRegressor(random_state=STATE)

params_dtr_model = {'max_depth': range(1, 11)}

grid_dtr_model = GridSearchCV(dtr_model, params_dtr_model, cv=5, scoring=smape_scorer)

grid_dtr_model.fit(features_train, target_train)

print('Лучшее значение sMAPE для модели DecisionTreeRegressor = ', grid_dtr_model.best_score_, 
      'при параметрах', grid_dtr_model.best_params_ )
# Out:
# Лучшее значение sMAPE для модели DecisionTreeRegressor =  -9.2667579604675 при параметрах {'max_depth': 3}

# %% [markdown]
# **Случайный лес**
#
# Аналогично обучим модель, используя автоматический подбор лучших гиперпараметров с помощью GridSearchCV, и оценим результат ее работы:

# %%
rfr_model = RandomForestRegressor(random_state=STATE, n_jobs=-1)

params_rfr_model = {'n_estimators': range(2, 33, 5),
                    'max_depth': range(1, 10, 2)}

grid_rfr_model = GridSearchCV(rfr_model, params_rfr_model, cv=5, scoring=smape_scorer)

grid_rfr_model.fit(features_train, target_train)

print('Лучшее значение sMAPE для модели RandomForestRegressor = ', grid_rfr_model.best_score_, 
      'при параметрах', grid_rfr_model.best_params_)
# Out:
# Лучшее значение sMAPE для модели RandomForestRegressor =  -8.715923245318901 при параметрах {'max_depth': 3, 'n_estimators': 22}

# %% [markdown]
# Оформим результат оценки качества моделей в таблицу:

# %%
score_data = pd.DataFrame(data=[10.1, 9.27, 8.72], 
                       index=['Линейная регрессия', 'Дерево решений', 'Случайный лес'],
                       columns=['Значение sMAPE'])

display(score_data.sort_values('Значение sMAPE'))
# Out:
#                     Значение sMAPE
# Случайный лес                 8.72
# Дерево решений                9.27
# Линейная регрессия           10.10

# %% [markdown]
# Лучший результат показала модель *RandomForestRegressor (random_state=STATE, n_jobs=-1, n_estimators=22 , max_depth=3)*. Значение *sMAPE* при данных гиперпараметрах равно 8.72

# %% [markdown]
# ### Тестирование модели
#
# Проведем проверку выбранной нами модели RandomForestRegressor *(random_state=STATE, n_jobs=-1, n_estimators=22, max_depth=3)* на тестовой выборке:

# %%
model = RandomForestRegressor (random_state=STATE, n_jobs=-1, n_estimators=22 , max_depth=3)

model.fit(features_train, target_train)
predicted_test = model.predict(features_test) # предсказания модели на тестовой выборке
score = final_smape(target_test, predicted_test) # значение метрики sMAPE на тестовой выборке
print('Значение sMAPE на тестовой выборке равно', score)
# Out:
# Значение sMAPE на тестовой выборке равно 7.32859731285912

# %% [markdown]
# Значение *sMAPE* нашей модели на тестовой выборке равно 7.33, что выше, чем на тренировочной (*sMAPE* = 8.72). Значит, наша модель не переобучилась и успешно прошла тест.

# %% [markdown]
# ### Проверка модели на адекватность
#
# Проверим модель на адекватность с помощью DummyRegressor - случайного регрессора с настройкой на постоянное предсказание среднего значения обучающей выборки:

# %%
dummy_model = DummyRegressor(strategy='mean')
dummy_model.fit(features_train, target_train)
dummy_predicted = dummy_model.predict(features_test)
score = final_smape(target_test, dummy_predicted)

print('Значение sMAPE константной модели на тестовой выборке равно', score)
# Out:
# Значение sMAPE константной модели на тестовой выборке равно 7.771047401701101

# %% [markdown]
# Проверка на адекватность пройдена - качество предсказания нашей модели выше, чем у константной модели (*sMAPE* равно 7.33 и 7.77 соответственно)

# %% [markdown]
# ### Вывод
#
# - Мы обучили на тренировочной выборке и оценили качество работы трех моделей: линейная регрессия, дерево решений и случайный лес. Для дерева решений и случайного леса производили подбор гиперпараметров с помощью *GridSearchCV*.
#
# - Лучшее значение метрики *sMAPE*, равное 8.72, показала модель *RandomForestRegressor (random_state=STATE, n_jobs=-1, n_estimators=22, max_depth=3)*.
#
# - Данная модель успешно показала себя на тестовой выборке - результат *sMAPE* = 7.33, а также прошла проверку на адекватность (*sMAPE* константной модели, постоянно предсказывающей среднее значение, равно 7.77, что ниже, чем у выбранной нами модели)

# %% [markdown]
# ### Общий вывод
#
# **Результат подготовки данных**
#
# - Явных дубликатов и проблем с типом данных не обнаружено. По условию задачи данные индексируются датой и временем получения информации, соседние по времени параметры часто похожи, поэтому мы установили столбец `date` в качестве индекса и заменили пропуски в исходном датасете на предшествующее нулю значение, далее пропуски в обучающей и тестовой выборках были заполнены данными из исходного датасета
#
# - Между некоторыми признаками есть сильная прямая либо обратная корреляция
#
# - Эффективность обогащения рассчитана правильно - *MAE* между нашим расчетом на обучающей выборке и значением признака `rougher.output.recovery` стремится к нулю
#
# - Признаки, отсутствующие в тестовой выборке - в основном, хвосты и консистенции металлов на различных этапах. Мы удалили данные признаки из обучающей выборки.
#
# **Результат анализа данных**
#
# - Построив график распределения концентрации металлов (Au, Ag, Pb) на различных этапах очистки, мы увидели:
#   - концентрация золота и свинца повышается с каждым этапом
#   - концентрация серебра увеличивается после флотации, затем идет на спад
#   - аномальные значения в районе нуля
#
# - График распределения размеров гранул сырья на обучающей и тестовой выборках показал схожее распределение
#
# - Суммарная концентрация веществ увеличивается на каждом этапе и достигает максимальных значения на этапе флотации и финальной стадии, однако, распределение в финальном концентрате более собранное
#
# - В суммарной концентрации веществ снова всплыли значения в районе нуля, которые мы удалили, оставив только значения больше 3
#
# **Результат работы с моделями**
#
# - Среди трех обученных нами моделей (линейная регрессия, дерево решений и случайный лес) лучшее значение метрики *sMAPE*, равное 8.72, показала модель *RandomForestRegressor (random_state=STATE, n_jobs=-1, n_estimators=22, max_depth=3)*
#
# - Результат *sMAPE* данной модели на тестовой выборке выше, чем на обучающей, и составляет 7.33. Выбранная нами модель также прошла проверку на адекватность (*sMAPE* константной модели, постоянно предсказывающей среднее значение, равно 7.77, что ниже, чем у выбранной нами модели)
